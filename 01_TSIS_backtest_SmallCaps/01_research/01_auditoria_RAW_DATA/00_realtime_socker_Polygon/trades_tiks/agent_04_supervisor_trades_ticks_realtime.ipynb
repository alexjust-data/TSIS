# %% [markdown]
# # Agent 04 Trades Ticks Supervisor
#
# Supervisor ligero para Agent01-03 de `trades_ticks`. Lee artefactos y persiste estado actual e historico del supervisor.

# %%
from pathlib import Path

RUN_ID = 'trades_ticks_prod_2005_2026'
RUN_DIR = Path(r'C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygon_realtime_audit') / RUN_ID
SCRIPT = Path(r'C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\204_agent4_supervisor_trades_ticks.py')

print('RUN_DIR:', RUN_DIR)
print('SCRIPT exists:', SCRIPT.exists())
# Out:
# RUN_DIR: C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygon_realtime_audit\trades_ticks_prod_2005_2026
# SCRIPT exists: True

# %%
cmd = f'''python {SCRIPT} --run-id {RUN_ID} --run-dir {RUN_DIR} --interval-sec 15 --stall-sec 180'''
print(cmd)
# Out:
# python C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\204_agent4_supervisor_trades_ticks.py --run-id trades_ticks_prod_2005_2026 --run-dir C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygon_realtime_audit\trades_ticks_prod_2005_2026 --interval-sec 15 --stall-sec 180

# %% [markdown]
# python C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\204_agent4_supervisor_trades_ticks.py --run-id trades_ticks_prod_2005_2026 --run-dir C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygon_realtime_audit\trades_ticks_prod_2005_2026 --interval-sec 15 --stall-sec 180

# %%
from pathlib import Path
import json
import pandas as pd

cur = RUN_DIR / 'trades_ticks_supervisor_current_status.json'
hist = RUN_DIR / 'trades_ticks_supervisor_events_history.csv'
print('current exists:', cur.exists())
print('history exists:', hist.exists())
if cur.exists():
    print(json.dumps(json.loads(cur.read_text(encoding='utf-8')), indent=2, ensure_ascii=False))
if hist.exists():
    display(pd.read_csv(hist).tail(20))
# Out:
# current exists: True
# history exists: True
# {
#   "updated_utc": "2026-03-18T09:48:03.279877+00:00",
#   "run_id": "trades_ticks_prod_2005_2026",
#   "run_dir": "C:\\TSIS_Data\\v1\\backtest_SmallCaps\\runs\\polygon_realtime_audit\\trades_ticks_prod_2005_2026",
#   "run_state": [
#     "AGENT01_RUNNING: descarga aun en progreso (pending=2067056)",
#     "AGENT02_REVIEW_QUEUE_OPEN: review_queue_pending_files_current=390380",
#     "AGENT03_RAW_ACCEPTED_REVIEW_PENDING",
#     "AGENT03_REVIEW_PENDING: review_queue_pending_files=375627"
#   ],
#   "warnings": [
#     "AGENT02_HARD_PRESENT: hard_fail_current=10481",
#     "AGENT03_REDLIST_PENDING: hard_fail_files=10474"
#   ],
#   "alerts": [
#     "AGENT01_STALL: live_status_trades_ticks_download sin actualizar > 180 s",
#     "AGENT02_STALL: live_status_trades_ticks_strict sin actualizar > 180 s",
#     "AGENT03_STALL: run_summary.json sin actualizar > 180 s"
#   ],
#   "agent01": {
#     "run_id": "trades_ticks_prod_2005_2026",
#     "updated_utc": "2026-03-18T07:59:12.545982+00:00",
#     "tasks_total": 3068656,
#     "done_ok": 1001600,
#     "done_bad": 0,
#     "pending": 2067056,
#     "session": "market",
#     "csv_path": "C:\\TSIS_Data\\v1\\backtest_SmallCaps\\runs\\polygon_realtime_audit\\trades_ticks_prod_2005_2026\\inputs\\tasks_trades_ticks.csv",
#     "output_root": "D:\\trades_ticks_prod_2005_2026",
#     "concurrent": 8,
#     "expected_manifest_csv": "C:\\TSIS_Data\\v1\\backtest_SmallCaps\\runs\\polygon_realtime_audit\\trades_ticks_prod_2005_2026\\expected_manifest_trades_ticks.csv",
#     "recommended_concurrency_policy": "stable_default",
#     "batch_metrics": {
#       "batch_tasks": 200,
#       "batch_ok": 193,
#       "batch_empty": 7,
#       "batch_fail": 0,
#       "batch_rows_total": 544255,
#       "batch_elapsed_sec": 66.877,
#       "batch_mean_task_sec": 1.9932,
#       "batch_tasks_per_sec": 2.9906
#     }
#   },
#   "agent02": {
#     "updated_utc": "2026-03-18T07:29:16.667214+00:00",
#     "probe_root": "D:\\trades_ticks_prod_2005_2026",
#     "max_files": 2000,
#     "files_discovered_total": 752782,
#     "files_pending": 390380,
#     "files_processed_total_state": 576000,
#     "files_current_snapshot": 576000,
#     "files_pending_delta_current": 2000,
#     "review_queue_pending_files_current": 390380,
#     "retry_pending_files_current": 390380,
#     "severity_counts_current": {
#       "SOFT_FAIL": 379899,
#       "PASS": 185620,
#       "HARD_FAIL": 10481
#     },
#     "top_causes_current": {
#       "duplicates_present_but_under_threshold": 333940,
#       "duplicate_excess_ratio_gt_threshold": 37245,
#       "duplicate_excess_ratio_gt_hard_cap": 10481,
#       "rows_lt_10": 8886
#     },
#     "expected_tasks_total": 3068656,
#     "validated_found_current": 576000,
#     "downloaded_ok_current": 754014,
#     "expected_tasks_missing_current": 2248070,
#     "expected_tasks_empty_current": 244586
#   },
#   "agent03": {
#     "run_id": "trades_ticks_prod_2005_2026",
#     "updated_utc": "2026-03-18T02:45:12.056073+00:00",
#     "tickers": 1962,
#     "tickers_observed": 590,
#     "tickers_validated": 438,
#     "events_rows_dedup": 554000,
#     "review_queue_pending_files": 375627,
#     "retry_pending_files": 375627,
#     "hard_fail_files": 10474,
#     "mean_coverage_ok": 0.17370169963873905,
#     "gate_status": "REVIEW_QUEUE_OPEN",
#     "acceptance_policy": "ACCEPT_ALL_RAW_REVIEW_LATER",
#     "raw_dataset_status": "RAW_ACCEPTED_REVIEW_PENDING",
#     "review_queue_semantics": "accept_all_raw_then_review_and_redlist",
# 23965  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...      ALERT
# 23966  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...      ALERT
# 23967  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...  RUN_STATE
# 23968  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...    WARNING
# 23969  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...    WARNING
# 23970  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...      ALERT
# 23971  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...      ALERT
# 23972  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...  RUN_STATE
# 23973  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...    WARNING
# 23974  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...    WARNING
# 23975  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...      ALERT
# 23976  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...      ALERT
# 23977  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...  RUN_STATE
# 23978  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...    WARNING
# 23979  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...    WARNING
# 23980  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...      ALERT
# 23981  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...      ALERT
# 23982  C:\TSIS_Data\v1\backtest_SmallCaps\runs\polygo...      ALERT
#
#                                                  message
# 23963      AGENT02_HARD_PRESENT: hard_fail_current=10481
# 23964     AGENT03_REDLIST_PENDING: hard_fail_files=10474
# 23965  AGENT02_STALL: live_status_trades_ticks_strict...
# 23966  AGENT03_STALL: run_summary.json sin actualizar...
# 23967  AGENT01_RUNNING: descarga aun en progreso (pen...
# 23968      AGENT02_HARD_PRESENT: hard_fail_current=10481
# 23969     AGENT03_REDLIST_PENDING: hard_fail_files=10474
# 23970  AGENT02_STALL: live_status_trades_ticks_strict...
# 23971  AGENT03_STALL: run_summary.json sin actualizar...
# 23972  AGENT01_RUNNING: descarga aun en progreso (pen...
# 23973      AGENT02_HARD_PRESENT: hard_fail_current=10481
# 23974     AGENT03_REDLIST_PENDING: hard_fail_files=10474
# 23975  AGENT02_STALL: live_status_trades_ticks_strict...
# 23976  AGENT03_STALL: run_summary.json sin actualizar...
# 23977  AGENT01_RUNNING: descarga aun en progreso (pen...
# 23978      AGENT02_HARD_PRESENT: hard_fail_current=10481
# 23979     AGENT03_REDLIST_PENDING: hard_fail_files=10474
# 23980  AGENT01_STALL: live_status_trades_ticks_downlo...
# 23981  AGENT02_STALL: live_status_trades_ticks_strict...
# 23982  AGENT03_STALL: run_summary.json sin actualizar...
