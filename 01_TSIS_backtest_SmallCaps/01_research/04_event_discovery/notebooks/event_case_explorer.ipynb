# %% [markdown]
# # Event Case Explorer
#
# Notebook lanzadera para Event Discovery. La logica vive en `01_research/04_event_discovery/scripts/`.
#
# Fuente operativa full-universe por defecto: `E:\\TSIS\\data\\ohlcv_1m`.
#
# `ohlcv_1m_split_normalized` queda como piloto/validacion split-aware, no como fuente full-universe.

# %%
import sys
from pathlib import Path

AREA_ROOT = Path(r"C:\\TSIS_Data\\01_TSIS_backtest_SmallCaps\\01_research\\04_event_discovery")
SCRIPTS_ROOT = AREA_ROOT / "scripts"
if str(SCRIPTS_ROOT) not in sys.path:
    sys.path.insert(0, str(SCRIPTS_ROOT))

from event_case_widgets import launch_event_discovery_app

launch_event_discovery_app()

# %% [markdown]
# ## Borrar un run exploratorio
#
# `C:\TSIS_Data\01_TSIS_backtest_SmallCaps\01_research\04_event_discovery\runs\first_day_3bar_push_gt_20pct_20260620T173406Z`
#
# Cada busqueda genera un run bajo `C:\\TSIS_Data\\01_TSIS_backtest_SmallCaps\\01_research\\04_event_discovery\\runs\\`.
#
# Para borrar un run concreto desde PowerShell:
#
# ```powershell
# Remove-Item -LiteralPath 'C:\\TSIS_Data\\01_TSIS_backtest_SmallCaps\\01_research\\04_event_discovery\\runs\\<run_id>' -Recurse -Force
# ```
#
# Sustituye `<run_id>` por la carpeta real que imprime el script, por ejemplo `first_day_3bar_push_gt_20pct_YYYYMMDDTHHMMSSZ`.

# %% [markdown]
# ## TradingView
#
# Celda auxiliar para abrir un chart gratuito de TradingView del ticker que quieras inspeccionar. El rango exacto se navega dentro del widget de TradingView.

# %%
import sys
from pathlib import Path

AREA_ROOT = Path(r"C:\\TSIS_Data\\01_TSIS_backtest_SmallCaps\\01_research\\04_event_discovery")
SCRIPTS_ROOT = AREA_ROOT / "scripts"
if str(SCRIPTS_ROOT) not in sys.path:
    sys.path.insert(0, str(SCRIPTS_ROOT))

from event_case_widgets import tradingview_widget

# Cambia el simbolo a mano si quieres: NASDAQ:CCSC, NASDAQ:BNGO, etc.
tradingview_widget(symbol="NASDAQ:sXTC", interval="1")
# Out:
#     <div class="tradingview-widget-container" style="height:760px;width:100%">
#       <div id="tradingview_event_discovery" style="height:100%;width:100%"></div>
#       <script type="text/javascript" src="https://s3.tradingview.com/tv.js"></script>
#       <script type="text/javascript">
#       new TradingView.widget({
#         "autosize": true,
#         "symbol": "NASDAQ:sXTC",
#         "interval": "1",
#         "timezone": "America/New_York",
#         "theme": "light",
#         "style": "1",
#         "locale": "en",
#         "enable_publishing": false,
#         "allow_symbol_change": true,
#         "calendar": false,
#         "container_id": "tradingview_event_discovery"
#       });
#       </script>
#     </div>
